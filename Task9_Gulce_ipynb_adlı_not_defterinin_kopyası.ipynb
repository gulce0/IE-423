# %% [markdown]
# <a href="https://colab.research.google.com/github/gulce0/IE-423/blob/main/Task9_Gulce_ipynb_adl%C4%B1_not_defterinin_kopyas%C4%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![utexas_ds_orie_divider.png](data:image/png;base64,...)

# %% [markdown]
# ## <font color='#475468'> Pretrained Models:</font>
# ### <font color='#475468'> Can you speed up your efforts using pretrained models?</font>

# %% [markdown]
# ![utexas_ds_orie_divider.png](data:image/png;base64,...)

# %% [markdown]
# # Transfomers
#
# Pretrained chains of models that perform specific tasks

# %% [markdown]
# ## Initialize

# %%
# !pip install transformers

# %%
# Use pipelines to access pre-trained models
from transformers import pipeline

# %% [markdown]
# ## Sentiment Analysis

# %%
# Model
mdlSnt = pipeline('sentiment-analysis')

# Parameters
prmStatement = ['I am happy to share that i will be working as a Data Science intern in İstanbul however, by doing so, i will not go on a holiday.']

# Predict
mdlSnt(prmStatement)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# ...

# %% [markdown]
# Can perform sentiment analysis in other languages as well using `model = 'nlptown/bert-base-multilingual-uncased-sentiment'`

# %%
# Model
mdlSnt = pipeline('sentiment-analysis', model = 'nlptown/bert-base-multilingual-uncased-sentiment')

# Parameters
prmStatement = 'Es war schön, dich zu sehen' #germah for: it was nice to see you

# Predict
mdlSnt(prmStatement)
# Out:
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/669M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/872k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# [{'label': '5 stars', 'score': 0.5431138277053833}]

# %% [markdown]
# The result is in stars as opposed to score... this is as per the model definition.  See model details in HF for more details.

# %% [markdown]
# ## Question Answering

# %% [markdown]
# ### Example 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Model
mdlQa = pipeline("question-answering")

# Parameters
f = open("/content/drive/MyDrive/Colab Notebooks/data/obster/yg.txt", "r")
context = f.read()
#context = "Bilkent University was founded in 1984 by Prof. İhsan Dogramacı and is recognized as one of the leading higher education institutions in Turkey."
question = "Where is Bilkent University?"

# Predict
mdlQa(question = question, context = context)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# {'score': 0.9157001972198486, 'start': 137, 'end': 143, 'answer': 'Turkey'}

# %% [markdown]
# ### Example 2

# %%
# Model
mdlQa = pipeline("question-answering")

# Parameters
f = open("/content/drive/MyDrive/Colab Notebooks/data/obster/yg.txt", "r")
context = f.read()
question = "Do Clash of Clans and Clash Royal have same publisher?"

# Predict
mdlQa(question = question, context = context)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.
# {'score': 0.7741779088973999, 'start': 223, 'end': 232, 'answer': 'Supercell'}

# %% [markdown]
# # Generative Pretrained Transformers

# %% [markdown]
# ## Initialize

# %%
# !pip install --upgrade pip
# !pip install openai==0.28
# Out:
# ...
#   Using cached pip-24.2-py3-none-any.whl.metadata (3.6 kB)
# Using cached pip-24.2-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
# !pip install colab-env -qU
import colab_env
# Out:
#   Preparing metadata (setup.py) ... done
# ...
# Mounted at /content/gdrive
